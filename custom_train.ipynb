# %%
import ultralytics

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

# %%
from ultralytics import YOLO

# Load model
model = YOLO("yolov8s.pt")   # nano version, fastest

# Train using GPU
model.train(
    data=r"C:\Users\KULDIP\OneDrive\Desktop\Bluepixel\DL\YOLO\Num_plate\data.yaml",
    epochs=5,
    imgsz=320,
    batch=32,          # little higher batch for GPU, adjust if OOM
    device=0,         # <--- USE GPU
    workers=2,        # Windows safe
    optimizer="SGD",
    pretrained=True,
    amp=True          # <--- MIXED PRECISION = fastest
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.233 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.231  Python-3.12.10 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...

# %%
model = YOLO(r"runs/detect/train/weights/best.pt")


results = model("test/images/00e8e5e79255536f_jpg.rf.04e24b86d0c062773ed207e247043b8c.jpg", save=True,conf=0.55)
# Out:
# image 1/1 c:\Users\KULDIP\OneDrive\Desktop\Bluepixel\DL\YOLO\Num_plate\test\images\00e8e5e79255536f_jpg.rf.04e24b86d0c062773ed207e247043b8c.jpg: 288x512 1 License_Plate, 40.5ms
# Speed: 4.1ms preprocess, 40.5ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
# Results saved to C:\Users\KULDIP\OneDrive\Desktop\Bluepixel\DL\YOLO\Num_plate\runs\detect\predict9
