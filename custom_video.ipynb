# %%
from ultralytics import YOLO
import cv2

# %%
model = YOLO(r"C:\Users\KULDIP\OneDrive\Desktop\Bluepixel\DL\YOLO\Num_plate\runs\detect\train\weights\best.pt")

# %%
input_path = r"car_num.mp4"
output_path = r"runs\detect\car_num.mp4"

# %%
cap = cv2.VideoCapture(input_path)

# %%
fps = cap.get(cv2.CAP_PROP_FPS)
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# %%
fourcc = cv2.VideoWriter_fourcc(*"mp4v")  
out = cv2.VideoWriter(output_path, fourcc, fps, (w, h))

# %%
while True:  # <-- break can only be used inside this loop
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)
    annotated_frame = results[0].plot()

    cv2.imshow("YOLO Video", annotated_frame)

    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# 0: 288x512 2 License_Plates, 91.7ms
# Speed: 9.0ms preprocess, 91.7ms inference, 4.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 6.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 15.0ms
# Speed: 1.6ms preprocess, 15.0ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 15.5ms
# Speed: 1.7ms preprocess, 15.5ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 14.7ms
# Speed: 1.7ms preprocess, 14.7ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 19.0ms
# Speed: 1.6ms preprocess, 19.0ms inference, 3.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 13.2ms
# Speed: 1.8ms preprocess, 13.2ms inference, 3.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 13.8ms
# Speed: 1.9ms preprocess, 13.8ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 13.9ms
# Speed: 1.5ms preprocess, 13.9ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 13.1ms
# Speed: 1.5ms preprocess, 13.1ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 13.9ms
# Speed: 2.0ms preprocess, 13.9ms inference, 4.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 22.4ms
# Speed: 2.0ms preprocess, 22.4ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 15.4ms
# Speed: 3.1ms preprocess, 15.4ms inference, 5.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 13.4ms
# Speed: 2.1ms preprocess, 13.4ms inference, 4.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 5.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 17.6ms
# Speed: 1.6ms preprocess, 17.6ms inference, 4.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 17.6ms
# Speed: 2.3ms preprocess, 17.6ms inference, 6.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 14.8ms
# Speed: 1.7ms preprocess, 14.8ms inference, 4.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 18.1ms
# Speed: 1.8ms preprocess, 18.1ms inference, 7.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 14.8ms
# Speed: 2.0ms preprocess, 14.8ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 16.5ms
# Speed: 2.5ms preprocess, 16.5ms inference, 5.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 17.4ms
# Speed: 1.8ms preprocess, 17.4ms inference, 6.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 16.6ms
# Speed: 1.9ms preprocess, 16.6ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 14.5ms
# Speed: 1.7ms preprocess, 14.5ms inference, 4.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 17.4ms
# Speed: 2.6ms preprocess, 17.4ms inference, 6.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 16.8ms
# Speed: 1.5ms preprocess, 16.8ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 17.3ms
# Speed: 1.5ms preprocess, 17.3ms inference, 5.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 15.7ms
# Speed: 1.9ms preprocess, 15.7ms inference, 5.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 16.6ms
# Speed: 1.7ms preprocess, 16.6ms inference, 4.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 16.3ms
# Speed: 2.0ms preprocess, 16.3ms inference, 4.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 14.1ms
# Speed: 1.4ms preprocess, 14.1ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 12.9ms
# Speed: 2.1ms preprocess, 12.9ms inference, 4.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 13.1ms
# Speed: 2.1ms preprocess, 13.1ms inference, 4.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 10.6ms
# Speed: 1.5ms preprocess, 10.6ms inference, 5.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 13.9ms
# Speed: 2.2ms preprocess, 13.9ms inference, 4.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 13.7ms
# Speed: 1.2ms preprocess, 13.7ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 License_Plates, 16.1ms
# Speed: 1.2ms preprocess, 16.1ms inference, 5.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 License_Plates, 12.1ms
# Speed: 1.7ms preprocess, 12.1ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 12.2ms
# Speed: 1.6ms preprocess, 12.2ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 12.1ms
# Speed: 1.2ms preprocess, 12.1ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 14.3ms
# Speed: 1.8ms preprocess, 14.3ms inference, 4.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 15.1ms
# Speed: 1.6ms preprocess, 15.1ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 License_Plates, 13.6ms
# Speed: 2.1ms preprocess, 13.6ms inference, 6.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 12.7ms
# Speed: 1.7ms preprocess, 12.7ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 12.1ms
# Speed: 2.4ms preprocess, 12.1ms inference, 6.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 License_Plates, 14.0ms
# Speed: 1.6ms preprocess, 14.0ms inference, 5.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 13.0ms
# Speed: 2.1ms preprocess, 13.0ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 License_Plates, 13.9ms
# Speed: 1.6ms preprocess, 13.9ms inference, 5.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 13.8ms
# Speed: 1.8ms preprocess, 13.8ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 13.3ms
# Speed: 1.6ms preprocess, 13.3ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 5.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 11.2ms
# Speed: 1.8ms preprocess, 11.2ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 5.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 9.6ms
# Speed: 1.2ms preprocess, 9.6ms inference, 5.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 13.2ms
# Speed: 2.3ms preprocess, 13.2ms inference, 5.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 14.4ms
# Speed: 2.4ms preprocess, 14.4ms inference, 5.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 14.2ms
# Speed: 1.5ms preprocess, 14.2ms inference, 9.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 22.2ms
# Speed: 2.3ms preprocess, 22.2ms inference, 5.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 13.8ms
# Speed: 2.0ms preprocess, 13.8ms inference, 3.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 18.6ms
# Speed: 1.9ms preprocess, 18.6ms inference, 4.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 13.1ms
# Speed: 1.9ms preprocess, 13.1ms inference, 4.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 8.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 5.8ms
# Speed: 1.8ms preprocess, 5.8ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 12.4ms
# Speed: 1.2ms preprocess, 12.4ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 13.0ms
# Speed: 1.4ms preprocess, 13.0ms inference, 4.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 7.6ms
# Speed: 1.3ms preprocess, 7.6ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 4 License_Plates, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 12.2ms
# Speed: 1.2ms preprocess, 12.2ms inference, 4.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 6.6ms
# Speed: 1.1ms preprocess, 6.6ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 9.1ms
# Speed: 1.1ms preprocess, 9.1ms inference, 3.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 5.6ms
# Speed: 1.1ms preprocess, 5.6ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 8.7ms
# Speed: 1.7ms preprocess, 8.7ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 7.0ms
# Speed: 1.2ms preprocess, 7.0ms inference, 3.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 6.8ms
# Speed: 1.1ms preprocess, 6.8ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 6.0ms
# Speed: 1.1ms preprocess, 6.0ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 6.9ms
# Speed: 1.2ms preprocess, 6.9ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 6.3ms
# Speed: 1.2ms preprocess, 6.3ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 7.1ms
# Speed: 1.2ms preprocess, 7.1ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 8.8ms
# Speed: 1.1ms preprocess, 8.8ms inference, 3.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 5.4ms
# Speed: 1.0ms preprocess, 5.4ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 9.2ms
# Speed: 1.6ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 6.9ms
# Speed: 1.4ms preprocess, 6.9ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 7.8ms
# Speed: 1.2ms preprocess, 7.8ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 7.3ms
# Speed: 1.1ms preprocess, 7.3ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 3 License_Plates, 7.3ms
# Speed: 1.7ms preprocess, 7.3ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 12.7ms
# Speed: 1.3ms preprocess, 12.7ms inference, 5.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 6.0ms
# Speed: 1.7ms preprocess, 6.0ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 7.1ms
# Speed: 1.1ms preprocess, 7.1ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 12.0ms
# Speed: 1.3ms preprocess, 12.0ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 7.7ms
# Speed: 1.3ms preprocess, 7.7ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 7.6ms
# Speed: 1.2ms preprocess, 7.6ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 7.7ms
# Speed: 1.1ms preprocess, 7.7ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 2.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 5.5ms
# Speed: 1.1ms preprocess, 5.5ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 12.1ms
# Speed: 1.5ms preprocess, 12.1ms inference, 3.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 5.9ms
# Speed: 1.1ms preprocess, 5.9ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.4ms
# Speed: 1.7ms preprocess, 5.4ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 6.7ms
# Speed: 1.2ms preprocess, 6.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.7ms
# Speed: 1.0ms preprocess, 5.7ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 12.2ms
# Speed: 1.2ms preprocess, 12.2ms inference, 3.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 8.3ms
# Speed: 1.1ms preprocess, 8.3ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.9ms
# Speed: 1.1ms preprocess, 5.9ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 6.6ms
# Speed: 1.2ms preprocess, 6.6ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 7.6ms
# Speed: 1.0ms preprocess, 7.6ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 9.6ms
# Speed: 1.0ms preprocess, 9.6ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.4ms
# Speed: 1.0ms preprocess, 5.4ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.2ms
# Speed: 1.0ms preprocess, 5.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 6.3ms
# Speed: 1.0ms preprocess, 6.3ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.4ms
# Speed: 1.1ms preprocess, 5.4ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.9ms
# Speed: 1.1ms preprocess, 5.9ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 6.7ms
# Speed: 1.0ms preprocess, 6.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 5.7ms
# Speed: 1.0ms preprocess, 5.7ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 5.9ms
# Speed: 1.1ms preprocess, 5.9ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 7.1ms
# Speed: 1.1ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 6.9ms
# Speed: 1.0ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 5.6ms
# Speed: 1.2ms preprocess, 5.6ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 7.2ms
# Speed: 1.1ms preprocess, 7.2ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 7.3ms
# Speed: 1.1ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 7.1ms
# Speed: 1.3ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 6.1ms
# Speed: 1.1ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 8.5ms
# Speed: 1.2ms preprocess, 8.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 7.0ms
# Speed: 1.1ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 2.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.6ms
# Speed: 1.0ms preprocess, 5.6ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 6.7ms
# Speed: 1.1ms preprocess, 6.7ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 9.5ms
# Speed: 1.3ms preprocess, 9.5ms inference, 3.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 7.2ms
# Speed: 2.2ms preprocess, 7.2ms inference, 1.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 7.6ms
# Speed: 1.1ms preprocess, 7.6ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 8.4ms
# Speed: 1.2ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 8.0ms
# Speed: 1.3ms preprocess, 8.0ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.8ms
# Speed: 2.0ms preprocess, 5.8ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.8ms
# Speed: 1.0ms preprocess, 5.8ms inference, 1.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 10.0ms
# Speed: 1.2ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 7.9ms
# Speed: 1.2ms preprocess, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 7.7ms
# Speed: 1.4ms preprocess, 7.7ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 10.1ms
# Speed: 1.5ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 7.8ms
# Speed: 1.0ms preprocess, 7.8ms inference, 1.8ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 7.3ms
# Speed: 1.2ms preprocess, 7.3ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 6.1ms
# Speed: 1.2ms preprocess, 6.1ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 5.9ms
# Speed: 1.1ms preprocess, 5.9ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 5.4ms
# Speed: 2.0ms preprocess, 5.4ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 7.9ms
# Speed: 1.0ms preprocess, 7.9ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.7ms
# Speed: 1.1ms preprocess, 5.7ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 10.0ms
# Speed: 1.3ms preprocess, 10.0ms inference, 3.7ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 5.8ms
# Speed: 1.9ms preprocess, 5.8ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.5ms
# Speed: 1.0ms preprocess, 5.5ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.3ms
# Speed: 1.1ms preprocess, 5.3ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 (no detections), 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.9ms
# Speed: 1.6ms preprocess, 5.9ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 4.9ms
# Speed: 1.0ms preprocess, 4.9ms inference, 1.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 6.5ms
# Speed: 1.0ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 2.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.3ms
# Speed: 1.0ms preprocess, 5.3ms inference, 1.9ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 3.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 7.1ms
# Speed: 1.2ms preprocess, 7.1ms inference, 2.4ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 5.6ms
# Speed: 1.2ms preprocess, 5.6ms inference, 1.5ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 6.8ms
# Speed: 1.1ms preprocess, 6.8ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 2.1ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 1 License_Plate, 5.6ms
# Speed: 1.1ms preprocess, 5.6ms inference, 1.6ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 6.0ms
# Speed: 1.1ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 2.2ms postprocess per image at shape (1, 3, 288, 512)
#
# 0: 288x512 2 License_Plates, 6.1ms
# Speed: 1.1ms preprocess, 6.1ms inference, 2.7ms postprocess per image at shape (1, 3, 288, 512)

# %%
out.write(annotated_frame)

# %%
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
print("Done! Saved:", output_path)
# Out:
# Done! Saved: runs\detect\car_num.mp4
